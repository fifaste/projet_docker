# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'dm_office_sales.csv'
df = pd.read_csv(url)
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
sns.scatterplot(data = df, x = "salary", y = "sales")
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(data = df, x = "salary", y = "sales")
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(data = df, x = "salary", y = "sales", hue='division')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(data = df, x = "salary", y = "sales", hue='work experience')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(data = df, x = "salary", y = "sales", hue='division', palette='viridis')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(data = df, x = "salary", y = "sales", style='work experience')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(data = df, x = "salary", y = "sales", style='level of education', hue='level of education', s=1000)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
# Exporter une figure sur seaborn

# %%
plt.savefig('plot.png')
plt.figure(figsize = (12,8))
sns.scatterplot(data = df, x = "salary", y = "sales", style='level of education', hue='level of education', s=1000)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>
